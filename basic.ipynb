# %% [markdown]
# ## A simple API call...maybe too simple?

# %%
# %pip install pandas

# %%
import pandas as pd, requests

df = pd.DataFrame(requests.get('https://api.sportsworldcentral.com/v0/teams').json())

display(df)
# Out:
#     league_id  team_id               team_name last_changed_date  \
# 0        5001     1001         Roaring Kitties        2024-04-23
# 1        5001     1002           Pigskin Party        2024-04-23
# 2        5001     1003           Dallas Steers        2024-04-23
# 3        5001     1004     Never Gonna Give Up        2024-04-23
# 4        5001     1005        Fighting Catfish        2024-04-23
# 5        5001     1006            Wallaby Stew        2024-04-23
# 6        5001     1007      Checkers Not Chess        2024-04-23
# 7        5001     1008        Defending Champs        2024-04-23
# 8        5001     1009            Team Generic        2024-04-23
# 9        5001     1010            Fumblerooski        2024-04-23
# 10       5001     1011           Double Option        2024-04-23
# 11       5001     1012          Wicked Awesome        2024-04-23
# 12       5002     1013      The Gridiron Goons        2024-04-23
# ...
